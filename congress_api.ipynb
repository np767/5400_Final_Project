# %% [markdown]
# # Congress API
#
# Link: https://api.congress.gov/sign-up/
#
# Step 1) API Key Sign Up

# %%
API_KEY = "gmgP7LxPn0NRrSTsAZr1dNIa5tBFSduUxmCd2qC8"  # erinabruzzy API key
BASE_URL = "https://api.congress.gov/v3/member"

# %%
import requests
import pandas as pd

params = {
    "api_key": API_KEY,
    "format": "json",
}

response = requests.get(BASE_URL, params=params)

if response.status_code == 200:
    data = response.json()

    # view first 5 members
    for member in data.get("members", [])[:5]:
        print(
            f"{member['name']} ({member['partyName']}) - {member['state']} "
            f"→ {member['url']}"
        )
# Out:
# Whitesides, George (Democratic) - California → https://api.congress.gov/v3/member/W000830?format=json
# Fine, Randy (Republican) - Florida → https://api.congress.gov/v3/member/F000484?format=json
# Patronis, Jimmy (Republican) - Florida → https://api.congress.gov/v3/member/P000622?format=json
# Vindman, Eugene Simon (Democratic) - Virginia → https://api.congress.gov/v3/member/V000138?format=json
# Taylor, David J. (Republican) - Ohio → https://api.congress.gov/v3/member/T000490?format=json

# %%
resp = requests.get(
    "https://api.congress.gov/v3/hearing/118",
    params={"api_key": API_KEY, "format": "json"}
)

data = resp.json()

# view one hearing
first_hearing = data["hearings"][0]
print(first_hearing)
print("\nDetail URL:", first_hearing["url"])
# Out:
# {'chamber': 'House', 'congress': 118, 'jacketNumber': 58105, 'updateDate': '2025-10-16T01:21:10Z', 'url': 'https://api.congress.gov/v3/hearing/118/house/58105'}
#
# Detail URL: https://api.congress.gov/v3/hearing/118/house/58105

# %%
detail_resp = requests.get(
    first_hearing["url"],
    params={"api_key": API_KEY, "format": "json"}
)

hearing_detail = detail_resp.json()

import json
print(json.dumps(hearing_detail, indent=2))

hearing_detail.keys()
# Out:
# {
#   "hearing": {
#     "associatedMeeting": {
#       "eventId": "116147",
#       "url": "https://api.congress.gov/v3/committee-meeting/118/house/116147?format=json"
#     },
#     "chamber": "House",
#     "citation": "H.Hrg.118",
#     "committees": [
#       {
#         "name": "House Energy and Commerce Committee",
#         "systemCode": "hsif00",
#         "url": "https://api.congress.gov/v3/committee/house/hsif00?format=json"
#       }
#     ],
#     "congress": 118,
#     "dates": [
#       {
#         "date": "2023-06-22"
#       }
#     ],
#     "formats": [
#       {
#         "type": "Formatted Text",
#         "url": "https://congress.gov/118/chrg/CHRG-118hhrg58105/generated/CHRG-118hhrg58105.htm"
#       },
#       {
#         "type": "PDF",
#         "url": "https://congress.gov/118/chrg/CHRG-118hhrg58105/CHRG-118hhrg58105.pdf"
#       }
#     ],
#     "jacketNumber": 58105,
#     "libraryOfCongressIdentifier": "LC74814",
#     "title": "MACRA CHECKUP: ASSESSING IMPLEMENTATION AND CHALLENGES THAT REMAIN FOR PATIENTS AND DOCTORS",
#     "updateDate": "2025-10-16T01:21:10Z"
#   },
#   "request": {
#     "chamber": "house",
#     "congress": "118",
#     "contentType": "application/json",
#     "format": "json",
#     "jacketNumber": "58105"
#   }
# }
# dict_keys(['hearing', 'request'])

# %% [markdown]
# ### Rate Limit
#
# The rate limit is set to 5,000 requests per hour.
